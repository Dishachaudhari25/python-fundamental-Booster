# %%
print("Welcome to the Interactive personal Data Collector !")

Name = input("Enter your Name: ")
Age = int(input("Enter your Age: "))
Height = float(input("Enter your Height in meters: "))
Favourite_Number = int(input("Enter your Favourite Number: "))

print("Thank you! Here is the information we collected: ")

print("Name: ",Name, "(Type: ",type(Name), "Memory Address: ", id(Name),")")
print("Age: ",Age, "(Type: ",type(Age), "Memory Address: ", id(Age),")")
print("Height: ",Height, "(Type: ",type(Height), "Memory Address: ", id(Height),")")
print("Favourite Number: ",Favourite_Number, "(Type: ",type(Favourite_Number), "Memory Address: ", id(Favourite_Number),")")

current_year = 2025
birth_year = current_year - Age

print("Your birth year is approximately: ",birth_year, "(based on your age of)", Age)

print("Thank you for using the Personal Data Collector. Goodbye!")
# Out:
# Welcome to the Interactive personal Data Collector !
# Enter your Name:  Disha
# Enter your Age:  19
# Enter your Height in meters:  56.9
# Enter your Favourite Number:  10
# Thank you! Here is the information we collected:
# Name:  Disha  (Type:  <class 'str'> Memory Address:  2381582060592 )
# Age:  19 (Type:  <class 'int'> Memory Address:  140727829313000 )
# Height:  56.9 (Type:  <class 'float'> Memory Address:  2381581832208 )
# Favourite Number:  10 (Type:  <class 'int'> Memory Address:  140727829312712 )
# Your birth year is approximately:  2006 (based on your age of) 19
# Thank you for using the Personal Data Collector. Goodbye!
